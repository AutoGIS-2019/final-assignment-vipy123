# %%
# Final Assignment
# The aim of this assignment is to compare datasets of Helsinki public area register. 
# Especially I want to look into the differences between attributes of parks and streetspaces. 
# Both of these spaces contain similar structures such as pedestrian ways, grass fields, which have 
# similar attributes such as material and purpose. My goal is to find illogicalities and overlaps with 
# the attributes.

# %%
#Imports
import geopandas as gpd
import requests
import geojson

# %%
#More imports
import matplotlib
# %matplotlib inline
from shapely.geometry import Polygon, LineString, Point
import matplotlib.pyplot as plt
import shapely.speedups
import folium
import contextily as ctx
from pyproj import CRS
import pandas as pd

# %%
# I decided to use the open WFS service from Helsinki city to obtain the data.
# Specify the url for the backend. This data is the Helsinki public area register data from: 
# https://hri.fi/data/dataset/helsingin-kaupungin-yleisten-alueiden-rekisteri/resource/bccf9215-c1c8-4c19-92db-89d2cce2b150
url = 'https://kartta.hel.fi/ws/geoserver/avoindata/wfs'


# Specify parameters (read data in json format).
paramsEiLiikenne = dict(service='WFS', version='2.0.0', request='GetFeature',
                        typeName="YLRE_Katu_ja_viherosat_eiliikenne_alue", outputFormat='json')

paramsKevytLiikenne = dict(service='WFS', version='2.0.0', request='GetFeature',
                           typeName="YLRE_Katu_ja_viherosat_kevytliikenne_alue", outputFormat='json')
paramsKatuOsat = dict(service='WFS', version='2.0.0', request='GetFeature',
                      typeName="YLRE_Katuosat_alue", outputFormat='json')
paramsViherOsat = dict(service='WFS', version='2.0.0', request='GetFeature',
                      typeName="YLRE_Viherosat_alue", outputFormat='json')
# Fetch data from WFS using requests
rEL = requests.get(url, params=paramsEiLiikenne)
rKL = requests.get(url, params=paramsKevytLiikenne)
rKO = requests.get(url, params=paramsKatuOsat)
rVO = requests.get(url, params=paramsViherOsat)


# Create GeoDataFrame from geojson
dataEiLiikenne = gpd.GeoDataFrame.from_features(geojson.loads(rEL.content))
dataKevytLiikenne = gpd.GeoDataFrame.from_features(geojson.loads(rKL.content))
dataKatuOsat = gpd.GeoDataFrame.from_features(geojson.loads(rKO.content))
dataViherOsat = gpd.GeoDataFrame.from_features(geojson.loads(rVO.content))

# %%
# Let's see what's in the light traffic dataframe.
dataKevytLiikenne.head()
# Out:
#                                             geometry  osan_id  \
# 0  POLYGON ((25500658.274 6685745.716, 25500657.4...   493092
# 1  POLYGON ((25494334.832 6677635.674, 25494335.8...   483632
# 2  POLYGON ((25494339.181 6677637.325, 25494338.1...   483631
# 3  POLYGON ((25502227.896 6672291.430, 25502224.8...   511814
# 4  POLYGON ((25502280.427 6672197.271, 25502283.4...   511822
#
#    paakohde_tyyppi_id       paatyyppi  alakohde_tyyppi_id  \
# 0                   3  Kevyt liikenne                   9
# 1                   3  Kevyt liikenne                 450
# 2                   3  Kevyt liikenne                 310
# 3                   3  Kevyt liikenne                 450
# 4                   3  Kevyt liikenne                 450
#
#                alatyyppi  materiaali_id        materiaali  \
# 0    Yhdistetty jk ja pp            501    Asfalttibetoni
# 1         Puistokäytävät            501    Asfalttibetoni
# 2  Lämmitettävät portaat            511  Betoni - valettu
# 3         Puistokäytävät            121         Kivituhka
# 4         Puistokäytävät            121         Kivituhka
#
#   rakenteellinen_kunnossapito       talvikunnossapito  ... katualueen_id  \
# 0      Kaupunkiympäristö Pohj  Kaupunkiympäristö Pohj  ...           NaN
# 1     Kaupunkiympäristö Länsi   Ei talvikunnossapitoa  ...           NaN
# 2     Kaupunkiympäristö Länsi   Ei talvikunnossapitoa  ...           NaN
# 3       Kaupunkiympäristö Itä   Ei talvikunnossapitoa  ...           NaN
# 4       Kaupunkiympäristö Itä   Ei talvikunnossapitoa  ...           NaN
#
#   katualueen_nro  kadunpitopaatos_pvm  osan_nro osan_pituus osan_leveys  \
# 0            NaN                 None        17        74.5         4.6
# 1            NaN                 None       327         1.6         3.0
# 2            NaN                 None       326         1.8         2.5
# 3            NaN                 None        55       117.0         3.0
# 4            NaN                 None        59        18.1         2.8
#
#   osan_pinta_ala paivitetty_pvm  datanomistaja paivitetty_tietopalveluun
# 0        244.261     2016-10-12  Helsinki/YLRE                2019-12-29
# 1          5.800     2019-05-09  Helsinki/YLRE                2019-12-29
# 2          5.500     2019-05-09  Helsinki/YLRE                2019-12-29
# 3        352.641     2014-08-11  Helsinki/YLRE                2019-12-29
# 4         51.357     2014-08-12  Helsinki/YLRE                2019-12-29
#
# [5 rows x 34 columns]

# %%
# ...and what's in the green area parts dataframe
dataViherOsat.tail()
# Out:
#                                                 geometry  osan_id  \
# 86602  POLYGON ((25496338.395 6674649.587, 25496338.2...   557108
# 86603  POLYGON ((25496329.561 6674648.699, 25496333.2...   557109
# 86604  POLYGON ((25494300.932 6678709.470, 25494300.9...   557395
# 86605  POLYGON ((25494294.397 6678704.550, 25494294.0...   557396
# 86606  POLYGON ((25494300.932 6678709.470, 25494321.5...   557397
#
#        paakohde_tyyppi_id           paatyyppi  alakohde_tyyppi_id  \
# 86602                  24         Kukkakasvit                 277
# 86603                  28      Muu rakenneosa                 455
# 86604                   3      Kevyt liikenne                   9
# 86605                  23  Nurmikot ja niityt                 272
# 86606                  28      Muu rakenneosa                 455
#
#                  alatyyppi  materiaali_id        materiaali  \
# 86602             Perennat           1011  Iris pseudacorus
# 86603           Erotusalue            531            Sepeli
# 86604  Yhdistetty jk ja pp            501    Asfalttibetoni
# 86605             Nurmikko           1837  Oletusmateriaali
# 86606           Erotusalue           1837  Oletusmateriaali
#
#       rakenteellinen_kunnossapito      talvikunnossapito  ... osan_pituus  \
# 86602     Kaupunkiympäristö Länsi  Ei talvikunnossapitoa  ...         0.0
# 86603     Kaupunkiympäristö Länsi  Ei talvikunnossapitoa  ...         0.0
# 86604     Kaupunkiympäristö Länsi  Ei talvikunnossapitoa  ...        21.6
# 86605     Kaupunkiympäristö Länsi  Ei talvikunnossapitoa  ...         0.0
# 86606     Kaupunkiympäristö Länsi  Ei talvikunnossapitoa  ...         0.0
#
#        osan_leveys osan_pinta_ala               puiston_nimi  \
# 86602          0.0            1.5            HESPERIANPUISTO
# 86603          0.0            2.5            HESPERIANPUISTO
# 86604          0.0           65.0  Kuusamakujan puistokaista
# 86605          0.0           37.4  Kuusamakujan puistokaista
# 86606          0.0           30.1  Kuusamakujan puistokaista
#
#       viheralueen_kayttotarkoitus viheralueen_id  viheralueen_nro  osan_nro  \
# 86602  Asemakaavoitettu viheralue          15301              666       101
# 86603  Asemakaavoitettu viheralue          15301              666       102
# 86604  Asemakaavoitettu viheralue         234401            10262         1
# 86605  Asemakaavoitettu viheralue         234401            10262         2
# 86606  Asemakaavoitettu viheralue         234401            10262         3
#
#        paivitetty_pvm paivitetty_tietopalveluun
# 86602      2018-04-11                2019-12-29
# 86603      2018-04-11                2019-12-29
# 86604      2018-04-16                2019-12-29
# 86605      2018-04-16                2019-12-29
# 86606      2018-04-16                2019-12-29
#
# [5 rows x 26 columns]

# %%
# Let's extract the light traffic parts from the green area parts.
viherKL = dataViherOsat.loc[dataViherOsat['paakohde_tyyppi_id']==3]
viherKL.head()
# Out:
#                                              geometry  osan_id  \
# 3   POLYGON ((25500658.274 6685745.716, 25500657.4...   493092
# 7   POLYGON ((25494334.832 6677635.674, 25494335.8...   483632
# 8   POLYGON ((25494339.181 6677637.325, 25494338.1...   483631
# 17  POLYGON ((25502227.896 6672291.430, 25502224.8...   511814
# 24  POLYGON ((25502280.427 6672197.271, 25502283.4...   511822
#
#     paakohde_tyyppi_id       paatyyppi  alakohde_tyyppi_id  \
# 3                    3  Kevyt liikenne                   9
# 7                    3  Kevyt liikenne                 450
# 8                    3  Kevyt liikenne                 310
# 17                   3  Kevyt liikenne                 450
# 24                   3  Kevyt liikenne                 450
#
#                 alatyyppi  materiaali_id        materiaali  \
# 3     Yhdistetty jk ja pp            501    Asfalttibetoni
# 7          Puistokäytävät            501    Asfalttibetoni
# 8   Lämmitettävät portaat            511  Betoni - valettu
# 17         Puistokäytävät            121         Kivituhka
# 24         Puistokäytävät            121         Kivituhka
#
#    rakenteellinen_kunnossapito       talvikunnossapito  ... osan_pituus  \
# 3       Kaupunkiympäristö Pohj  Kaupunkiympäristö Pohj  ...        74.5
# 7      Kaupunkiympäristö Länsi   Ei talvikunnossapitoa  ...         1.6
# 8      Kaupunkiympäristö Länsi   Ei talvikunnossapitoa  ...         1.8
# 17       Kaupunkiympäristö Itä   Ei talvikunnossapitoa  ...       117.0
# 24       Kaupunkiympäristö Itä   Ei talvikunnossapitoa  ...        18.1
#
#     osan_leveys osan_pinta_ala            puiston_nimi  \
# 3           4.6        244.261          Korttelipuisto
# 7           3.0          5.800        KAUPPALANPUISTO
# 8           2.5          5.500        KAUPPALANPUISTO
# 17          3.0        352.641  HEVOSSALMEN ALUEPUISTO
# 24          2.8         51.357  HEVOSSALMEN ALUEPUISTO
#
#    viheralueen_kayttotarkoitus viheralueen_id  viheralueen_nro  osan_nro  \
# 3   Asemakaavoitettu viheralue          53341             2435        17
# 7   Asemakaavoitettu viheralue          18161              795       327
# 8   Asemakaavoitettu viheralue          18161              795       326
# 17  Asemakaavoitettu viheralue          15801              691        55
# 24  Asemakaavoitettu viheralue          15801              691        59
#
#     paivitetty_pvm paivitetty_tietopalveluun
# 3       2016-10-12                2019-12-29
# 7       2019-05-09                2019-12-29
# 8       2019-05-09                2019-12-29
# 17      2014-08-11                2019-12-29
# 24      2014-08-12                2019-12-29
#
# [5 rows x 26 columns]

# %%
# Then the same with street parts.
dataKatuOsat.head()
# Out:
#                                             geometry  osan_id  \
# 0  POLYGON ((25496885.290 6682951.550, 25496885.8...     8594
# 1  POLYGON ((25496189.585 6681434.554, 25496208.5...     8606
# 2  POLYGON ((25502552.384 6684650.157, 25502552.4...    10421
# 3  POLYGON ((25497327.295 6682760.955, 25497326.9...     4944
# 4  POLYGON ((25496843.683 6680784.244, 25496844.0...     5948
#
#    paakohde_tyyppi_id                    paatyyppi  alatyyppi  materiaali_id  \
# 0                  23           Nurmikot ja niityt        272            573
# 1                  23           Nurmikot ja niityt        272            573
# 2                   3               Kevyt liikenne          6            523
# 3                  25  Puut, pensaat ja köynnökset        281           1837
# 4                  27               Erityiskohteet        101           1837
#
#             materiaali       talvikunnossapito tkp_kiireellisyys_lk  \
# 0  Istutusalue - nurmi  Kaupunkiympäristö Pohj                 None
# 1  Istutusalue - nurmi  Kaupunkiympäristö Pohj                 None
# 2            Noppakivi  Kaupunkiympäristö Pohj                 None
# 3     Oletusmateriaali  Kaupunkiympäristö Pohj                 None
# 4     Oletusmateriaali  Kaupunkiympäristö Pohj                 None
#
#    laatutaso_id  ... katualueen_kayttotarkoitus kadunpitopaatos_pvm  \
# 0            71  ...       Kokoojakatu tai -tie          1991-10-15
# 1            71  ...                 Asuntokatu          1974-10-15
# 2             3  ...             Pysäköintialue          2008-08-14
# 3            73  ...       Kokoojakatu tai -tie          1987-10-30
# 4             2  ...       Kokoojakatu tai -tie          1971-11-02
#
#   katualueen_nro osan_nro osan_pituus  osan_leveys osan_pinta_ala  \
# 0           1330       86         0.0          0.0          2.213
# 1            190       44         0.0          0.0        105.094
# 2           1915        4         0.1          0.0          8.140
# 3           1326       54         0.0          0.0          1.497
# 4            233       23         0.0          0.0          4.800
#
#   paivitetty_pvm  datanomistaja  paivitetty_tietopalveluun
# 0     2015-12-04  Helsinki/YLRE                 2019-12-29
# 1     2015-12-04  Helsinki/YLRE                 2019-12-29
# 2     2015-12-04  Helsinki/YLRE                 2019-12-29
# 3     2015-12-04  Helsinki/YLRE                 2019-12-29
# 4     2015-12-04  Helsinki/YLRE                 2019-12-29
#
# [5 rows x 26 columns]

# %%
# Let's extract the light traffic parts from the street parts.
katuKL = dataKatuOsat.loc[dataKatuOsat['paakohde_tyyppi_id']==3]
katuKL.head()
# Out:
#                                              geometry  osan_id  \
# 2   POLYGON ((25502552.384 6684650.157, 25502552.4...    10421
# 24  POLYGON ((25499530.966 6681470.564, 25499567.6...     4688
# 34  POLYGON ((25499468.054 6680678.706, 25499469.1...     3789
# 42  POLYGON ((25497143.421 6680849.668, 25497143.5...     5634
# 64  POLYGON ((25496809.521 6682728.624, 25496807.4...     4743
#
#     paakohde_tyyppi_id       paatyyppi  alatyyppi  materiaali_id  \
# 2                    3  Kevyt liikenne          6            523
# 24                   3  Kevyt liikenne          7            516
# 34                   3  Kevyt liikenne          9            501
# 42                   3  Kevyt liikenne          7            501
# 64                   3  Kevyt liikenne          7            501
#
#         materiaali       talvikunnossapito tkp_kiireellisyys_lk  laatutaso_id  \
# 2        Noppakivi  Kaupunkiympäristö Pohj                 None             3
# 24      Betonikivi  Kaupunkiympäristö Pohj                 None             3
# 34  Asfalttibetoni  Kaupunkiympäristö Pohj                 None             3
# 42  Asfalttibetoni  Kaupunkiympäristö Pohj                 None             3
# 64  Asfalttibetoni  Kaupunkiympäristö Pohj                 None             2
#
#     ... katualueen_kayttotarkoitus kadunpitopaatos_pvm katualueen_nro  \
# 2   ...             Pysäköintialue          2008-08-14           1915
# 24  ...                 Asuntokatu          1993-10-01           1146
# 34  ...             Kevyt liikenne          1983-12-01           1093
# 42  ...       Kokoojakatu tai -tie          1967-11-16            249
# 64  ...    Kokoojakatu alueellinen          1982-12-01           1306
#
#    osan_nro osan_pituus  osan_leveys osan_pinta_ala paivitetty_pvm  \
# 2         4         0.1        0.000          8.140     2015-12-04
# 24        3        38.4        1.016         39.002     2015-12-04
# 34        5         2.0        3.550          7.093     2015-12-04
# 42        4        23.0        2.296         52.816     2015-12-04
# 64        3        63.8        4.200        159.402     2016-04-12
#
#     datanomistaja  paivitetty_tietopalveluun
# 2   Helsinki/YLRE                 2019-12-29
# 24  Helsinki/YLRE                 2019-12-29
# 34  Helsinki/YLRE                 2019-12-29
# 42  Helsinki/YLRE                 2019-12-29
# 64  Helsinki/YLRE                 2019-12-29
#
# [5 rows x 26 columns]

# %%
#Let's see what kind of types and use purposes there are in the ViherKL (Green area pedestrian ways)
print(viherKL['alatyyppi'].unique())
print(viherKL['viheralueen_kayttotarkoitus'].unique())
# Out:
# ['Yhdistetty jk ja pp' 'Puistokäytävät' 'Lämmitettävät portaat' 'Portaat'
#  'Jalankulkualue' 'Kevyt liikenne' 'Aukiot' 'Polku'
#  'Erotettu jalkakäytävä' 'Pelastusreitit' 'Ratsastusreitit'
#  'Erotettu pyörätie' 'Luontopolku' 'Pyöräilyalue']
# ['Asemakaavoitettu viheralue' 'Uimaranta-alue' 'Yleiskaavan viheralue'
#  'Muu toimiluokka' 'Suojaviheralue' 'Leikkipaikka' 'Luonnonsuojelualue'
#  'Leikkipuisto' 'Koira-aitaus'
#  'Erityiskohteet, asemakaavoitettu viheralue' 'Viljelypalsta-alue'
#  'Rata-alue' 'Saari (saaret ilman siltayhteyttä)'
#  'Kartano- ja huvila-alue' 'Yleiskaavan viheralue / luonnonsuojelualue'
#  'Tontti (rakentamattomat / sopimus)' 'Siirtolapuutarha' 'Kesämaja-alue'
#  'Yleiskaavan viheralue / viljelypalsta' 'Haudat (hautausmaat)'
#  'Ulkoilumetsä' 'Venesatama / Venevalkama'
#  'Yleiskaavan viheralue / kesämaja-alue' 'Toiminta-alue'
#  'Yleiskaavan viheralue / kartanoalue'
#  'Yleiskaavan viheralue / leikkipuisto'
#  'Yleiskaavan viheralue / erityiskohteet' 'Katualue'
#  'Yleiskaavan viheralue / leikkipaikka' 'Liikennealue']

# %%
# We want to have the similar subtype data in the street light traffic parts as in the green area 
# light traffic dataframe, so we need to combine the data from the dataframe that includes all light 
# traffic data.
# First rename the "alatyyppi"-column as "alatyyppi_id" as it should be. That's already one illogicality!
katuKL = katuKL.rename({'alatyyppi' : 'alatyyppi_id'}, axis=1)
# Let's make a new dataframe which only contains unique values of the sub types and their ids.
alatyypitKL = gpd.GeoDataFrame()
alatyypitKL['alakohde_tyyppi_id'] = dataKevytLiikenne['alakohde_tyyppi_id'].unique()
alatyypitKL['alatyyppi'] = dataKevytLiikenne['alatyyppi'].unique()
alatyypitKL
# Out:
#     alakohde_tyyppi_id                      alatyyppi
# 0                    9            Yhdistetty jk ja pp
# 1                  450                 Puistokäytävät
# 2                  310          Lämmitettävät portaat
# 3                   14                        Portaat
# 4                    7                 Jalankulkualue
# 5                  452                          Polku
# 6                    6                 Kevyt liikenne
# 7                  453                         Aukiot
# 8                  468         Kevyt liikenne (Silta)
# 9                  480                  Polku (Silta)
# 10                 471    Yhdistetty jk ja pp (Silta)
# 11                  10          Erotettu jalkakäytävä
# 12                 478         Puistokäytävät (Silta)
# 13                 448                 Pelastusreitit
# 14                 449                Ratsastusreitit
# 15                  11              Erotettu pyörätie
# 16                 451                    Luontopolku
# 17                 475                Portaat (Silta)
# 18                   8                   Pyöräilyalue
# 19                 474    Kevyt liikenne, muu (Silta)
# 20                 472  Erotettu jalkakäytävä (Silta)
# 21                 473      Erotettu pyörätie (Silta)
# 22                 479            Luontopolku (Silta)
# 23                 469         Jalankulkualue (Silta)
# 24                 470           Pyöräilyalue (Silta)
# 25                 481                 Aukiot (Silta)

# %%
# Have to acknowledge that we are working with huge dataframes that contain tens of thousands of rows.
len(katuKL)
# Out:
# 32859

# %%
# Add the alatyyppi string values to the katuKL dataframe.
# Create a new column as a series.
katuKL['alatyyppi'] = pd.Series(dtype = str)
# Iterate over street light traffic dataframe and apply the right values to each sub type.
for index, row in katuKL.iterrows():
    #Find the right value by the index
    rivi = alatyypitKL['alatyyppi'].loc[alatyypitKL['alakohde_tyyppi_id'] == row['alatyyppi_id']]
    
    solu = rivi.iloc[0]
    
    #Add the value to the cell of the dataframe
    katuKL.at[index,'alatyyppi'] = solu

# %%
# Now we have the string values of the sub types int he same data frame.
katuKL.tail()
# Out:
#                                                  geometry  osan_id  \
# 152574  POLYGON ((25494251.832 6678585.260, 25494252.2...   557347
# 152651  POLYGON ((25494277.442 6678634.883, 25494278.5...   557329
# 152674  POLYGON ((25496285.621 6677040.955, 25496285.9...   556449
# 152676  POLYGON ((25496867.453 6675922.881, 25496867.4...   556222
# 152745  POLYGON ((25494294.927 6678706.094, 25494298.6...   557378
#
#         paakohde_tyyppi_id       paatyyppi  alatyyppi_id  materiaali_id  \
# 152574                   3  Kevyt liikenne           453             82
# 152651                   3  Kevyt liikenne             7            501
# 152674                   3  Kevyt liikenne             9            501
# 152676                   3  Kevyt liikenne             7            501
# 152745                   3  Kevyt liikenne             9            501
#
#             materiaali        talvikunnossapito tkp_kiireellisyys_lk  \
# 152574   Graniittikivi  Kaupunkiympäristö Länsi                 None
# 152651  Asfalttibetoni  Kaupunkiympäristö Länsi                 None
# 152674  Asfalttibetoni   Kaupunkiympäristö Pohj                 None
# 152676  Asfalttibetoni   Kaupunkiympäristö Pohj                 None
# 152745  Asfalttibetoni  Kaupunkiympäristö Länsi                 None
#
#         laatutaso_id  ... kadunpitopaatos_pvm katualueen_nro osan_nro  \
# 152574             3  ...          2018-09-01           7782       17
# 152651             3  ...          2018-09-01           7782        3
# 152674             1  ...                None           9118       24
# 152676             2  ...          1932-01-01           5161       27
# 152745             3  ...          2018-09-01           7782       48
#
#        osan_pituus osan_leveys  osan_pinta_ala paivitetty_pvm  datanomistaja  \
# 152574         0.0         0.0            0.07     2018-04-13  Helsinki/YLRE
# 152651       139.8         0.0          420.60     2018-11-16  Helsinki/YLRE
# 152674        33.4         4.0          132.50     2018-03-23  Helsinki/YLRE
# 152676         0.1         0.0            1.40     2018-03-13  Helsinki/YLRE
# 152745         1.0         0.0            3.90     2018-04-16  Helsinki/YLRE
#
#         paivitetty_tietopalveluun            alatyyppi
# 152574                 2019-12-29               Aukiot
# 152651                 2019-12-29       Jalankulkualue
# 152674                 2019-12-29  Yhdistetty jk ja pp
# 152676                 2019-12-29       Jalankulkualue
# 152745                 2019-12-29  Yhdistetty jk ja pp
#
# [5 rows x 27 columns]

# %%
print(katuKL.crs)
#crs_object = 
katuKL.crs = CRS..from_epsg(4326)
#katuKL= katuKL.to_crs(crs_object)
# Out:
#   File "<ipython-input-190-a8b5507dcaff>", line 2
#     crs_object =
#                  ^
# SyntaxError: invalid syntax
